# %% [markdown]
# ## <font color='red' >Useful libraries and packages (contd.)</font>
# ***
# <body>
# <p><font face="Consolas">It's Python, there's rarely the need to re-invent the wheel!</font></p>
# </body>

# %% [markdown]
# ### pandas (Data Frames Made Easy)   https://pandas.pydata.org/
#
# #### pandas is an open source, easy-to-use data structures and data analysis tools for the Python programming language. Some highlights include:
# - A fast and efficient DataFrame object for data manipulation with integrated indexing;
# - Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
# - Intelligent data alignment and integrated handling of missing data: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
# - Flexible reshaping and pivoting of data sets;
# - Intelligent label-based slicing, fancy indexing, and subsetting of large data sets
#
# #### Python has long been great for data munging and preparation, but less so for data analysis and modeling. pandas helps fill this gap, enabling you to carry out your entire data analysis workflow in Python without having to switch to a more domain specific language like R.

# %% [markdown]
# To use pandas, we first need to import the `pandas` package:

# %%
import pandas as pd

# %% [markdown]
# We will also use `numpy` in some of the examples:

# %%
import numpy as np

# %% [markdown]
# A "list" in a pandas environment is known as a series:

# %%
s = pd.Series([1,4,3,9,np.nan,888])
s
# Out:
# 0      1.0
# 1      4.0
# 2      3.0
# 3      9.0
# 4      NaN
# 5    888.0
# dtype: float64

# %% [markdown]
# ### The first column is known as the 'index' in a pandas setting

# %% [markdown]
# A dataframe is a more formal structure in pandas. It contains column headers and is the most common type of pandas object to work with. Here, we will create a `pandas` DataFrame by passing a NumPy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20190211', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2019-02-11', '2019-02-12', '2019-02-13', '2019-02-14',
#                '2019-02-15', '2019-02-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=dates, columns = ['prob_RA','prob_SN','prob_ZR','prob_IP'])

# %%
df
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-11  0.509702  0.348442  0.831818  0.151038
# 2019-02-12  0.006093  0.723499  0.413321  0.716675
# 2019-02-13  0.112984  0.070426  0.531915  0.544648
# 2019-02-14  0.511436  0.760080  0.102810  0.160188
# 2019-02-15  0.640878  0.331538  0.084583  0.975434
# 2019-02-16  0.901837  0.697978  0.441523  0.443874

# %% [markdown]
# You can now access individual columns:

# %%
df.prob_RA
# Out:
# 2019-02-11    0.509702
# 2019-02-12    0.006093
# 2019-02-13    0.112984
# 2019-02-14    0.511436
# 2019-02-15    0.640878
# 2019-02-16    0.901837
# Freq: D, Name: prob_RA, dtype: float64

# %% [markdown]
# ..and make a nice plot!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.tight_layout()
plt.plot(df.prob_RA)

# %% [markdown]
# To access the specific values, use `.values`

# %%
df.prob_RA.values
# Out:
# array([0.50970203, 0.00609335, 0.11298437, 0.51143647, 0.64087763,
#        0.90183656])

# %% [markdown]
# To see the column data types, use `.dtypes`

# %%
df.dtypes
# Out:
# prob_RA    float64
# prob_SN    float64
# prob_ZR    float64
# prob_IP    float64
# dtype: object

# %% [markdown]
# ### You can create a DataFrame by using a dictonary:

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20190102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["snow", "rain", "freezing_rain", "sleet"]),
                    'F': 'weather'})

# %%
df2
# Out:
#      A          B    C  D              E        F
# 0  1.0 2019-01-02  1.0  3           snow  weather
# 1  1.0 2019-01-02  1.0  3           rain  weather
# 2  1.0 2019-01-02  1.0  3  freezing_rain  weather
# 3  1.0 2019-01-02  1.0  3          sleet  weather

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ### use `df.head()` and `df.tail()` for DataFrame previews:

# %%
df.head()
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-11  0.509702  0.348442  0.831818  0.151038
# 2019-02-12  0.006093  0.723499  0.413321  0.716675
# 2019-02-13  0.112984  0.070426  0.531915  0.544648
# 2019-02-14  0.511436  0.760080  0.102810  0.160188
# 2019-02-15  0.640878  0.331538  0.084583  0.975434

# %%
df.tail(2)
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-15  0.640878  0.331538  0.084583  0.975434
# 2019-02-16  0.901837  0.697978  0.441523  0.443874

# %% [markdown]
# Display the index, columns:

# %%
df.index
# Out:
# DatetimeIndex(['2019-02-11', '2019-02-12', '2019-02-13', '2019-02-14',
#                '2019-02-15', '2019-02-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['prob_RA', 'prob_SN', 'prob_ZR', 'prob_IP'], dtype='object')

# %% [markdown]
# `describe()` shows a quick statistic summary of your data:

# %%
df.describe()
# Out:
#         prob_RA   prob_SN   prob_ZR   prob_IP
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.447155  0.488661  0.400995  0.498643
# std    0.334220  0.279965  0.280562  0.321050
# min    0.006093  0.070426  0.084583  0.151038
# 25%    0.212164  0.335764  0.180437  0.231109
# 50%    0.510569  0.523210  0.427422  0.494261
# 75%    0.608517  0.717119  0.509317  0.673669
# max    0.901837  0.760080  0.831818  0.975434

# %% [markdown]
# Transposing your data:

# %%
df.T
# Out:
#          2019-02-11  2019-02-12  2019-02-13  2019-02-14  2019-02-15  \
# prob_RA    0.509702    0.006093    0.112984    0.511436    0.640878
# prob_SN    0.348442    0.723499    0.070426    0.760080    0.331538
# prob_ZR    0.831818    0.413321    0.531915    0.102810    0.084583
# prob_IP    0.151038    0.716675    0.544648    0.160188    0.975434
#
#          2019-02-16
# prob_RA    0.901837
# prob_SN    0.697978
# prob_ZR    0.441523
# prob_IP    0.443874

# %% [markdown]
# Sorting is easy:

# %%
df.sort_values(by='prob_RA', ascending=True)
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-12  0.006093  0.723499  0.413321  0.716675
# 2019-02-13  0.112984  0.070426  0.531915  0.544648
# 2019-02-11  0.509702  0.348442  0.831818  0.151038
# 2019-02-14  0.511436  0.760080  0.102810  0.160188
# 2019-02-15  0.640878  0.331538  0.084583  0.975434
# 2019-02-16  0.901837  0.697978  0.441523  0.443874

# %% [markdown]
# ## Selection

# %% [markdown]
# See the indexing documentation Indexing and Selecting Data and MultiIndex / Advanced Indexing.
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#indexing
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html#advanced

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.prob_RA:

# %%
df['prob_RA']
# Out:
# 2019-02-11    0.509702
# 2019-02-12    0.006093
# 2019-02-13    0.112984
# 2019-02-14    0.511436
# 2019-02-15    0.640878
# 2019-02-16    0.901837
# Freq: D, Name: prob_RA, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-11  0.509702  0.348442  0.831818  0.151038
# 2019-02-12  0.006093  0.723499  0.413321  0.716675
# 2019-02-13  0.112984  0.070426  0.531915  0.544648

# %%
df.loc[dates[0]]
# Out:
# prob_RA    0.509702
# prob_SN    0.348442
# prob_ZR    0.831818
# prob_IP    0.151038
# Name: 2019-02-11 00:00:00, dtype: float64

# %%
df.loc[:, ['prob_RA', 'prob_SN']]
# Out:
#              prob_RA   prob_SN
# 2019-02-11  0.509702  0.348442
# 2019-02-12  0.006093  0.723499
# 2019-02-13  0.112984  0.070426
# 2019-02-14  0.511436  0.760080
# 2019-02-15  0.640878  0.331538
# 2019-02-16  0.901837  0.697978

# %%
df.loc['20190213':'20190215', ['prob_RA', 'prob_SN']]
# Out:
#              prob_RA   prob_SN
# 2019-02-13  0.112984  0.070426
# 2019-02-14  0.511436  0.760080
# 2019-02-15  0.640878  0.331538

# %% [markdown]
# Selection by Position (Select via the position of the passed integers)

# %%
df.iloc[3]
# Out:
# prob_RA    0.511436
# prob_SN    0.760080
# prob_ZR    0.102810
# prob_IP    0.160188
# Name: 2019-02-14 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python:

# %%
df.iloc[3:5, 0:2]
# Out:
#              prob_RA   prob_SN
# 2019-02-14  0.511436  0.760080
# 2019-02-15  0.640878  0.331538

# %% [markdown]
# For slicing rows explicitly:

# %%
df.iloc[1:3, :]
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-12  0.006093  0.723499  0.413321  0.716675
# 2019-02-13  0.112984  0.070426  0.531915  0.544648

# %% [markdown]
# For slicing columns explicitly:

# %%
df.iloc[:, 1:3]
# Out:
#              prob_SN   prob_ZR
# 2019-02-11  0.348442  0.831818
# 2019-02-12  0.723499  0.413321
# 2019-02-13  0.070426  0.531915
# 2019-02-14  0.760080  0.102810
# 2019-02-15  0.331538  0.084583
# 2019-02-16  0.697978  0.441523

# %% [markdown]
# Using a single column’s values to select data.

# %%
df[df.prob_ZR > 0.5]
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-11  0.509702  0.348442  0.831818  0.151038
# 2019-02-13  0.112984  0.070426  0.531915  0.544648

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met.

# %%
df[df > 0.5]
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-11  0.509702       NaN  0.831818       NaN
# 2019-02-12       NaN  0.723499       NaN  0.716675
# 2019-02-13       NaN       NaN  0.531915  0.544648
# 2019-02-14  0.511436  0.760080       NaN       NaN
# 2019-02-15  0.640878       NaN       NaN  0.975434
# 2019-02-16  0.901837  0.697978       NaN       NaN

# %% [markdown]
# Copy, add a column, check some condition:

# %%
df2 = df.copy()

# %%
df2['planet'] = ['mars', 'venus', 'earth', 'saturn', 'jupiter', 'neptune']

# %%
df2
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP   planet
# 2019-02-11  0.509702  0.348442  0.831818  0.151038     mars
# 2019-02-12  0.006093  0.723499  0.413321  0.716675    venus
# 2019-02-13  0.112984  0.070426  0.531915  0.544648    earth
# 2019-02-14  0.511436  0.760080  0.102810  0.160188   saturn
# 2019-02-15  0.640878  0.331538  0.084583  0.975434  jupiter
# 2019-02-16  0.901837  0.697978  0.441523  0.443874  neptune

# %%
df2[df2['planet'].isin(['earth', 'mars'])]
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP planet
# 2019-02-11  0.509702  0.348442  0.831818  0.151038   mars
# 2019-02-13  0.112984  0.070426  0.531915  0.544648  earth

# %%
df[df > 0.5]
# Out:
#              prob_RA   prob_SN   prob_ZR   prob_IP
# 2019-02-11  0.509702       NaN  0.831818       NaN
# 2019-02-12       NaN  0.723499       NaN  0.716675
# 2019-02-13       NaN       NaN  0.531915  0.544648
# 2019-02-14  0.511436  0.760080       NaN       NaN
# 2019-02-15  0.640878       NaN       NaN  0.975434
# 2019-02-16  0.901837  0.697978       NaN       NaN

# %% [markdown]
# Drop data if NaN

# %%
df[df > 0.5].dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [prob_RA, prob_SN, prob_ZR, prob_IP]
# Index: []

# %% [markdown]
# Filling missing data.

# %%
df[df > 0.5].fillna(value=555)
# Out:
#                prob_RA     prob_SN     prob_ZR     prob_IP
# 2019-02-11    0.509702  555.000000    0.831818  555.000000
# 2019-02-12  555.000000    0.723499  555.000000    0.716675
# 2019-02-13  555.000000  555.000000    0.531915    0.544648
# 2019-02-14    0.511436    0.760080  555.000000  555.000000
# 2019-02-15    0.640878  555.000000  555.000000    0.975434
# 2019-02-16    0.901837    0.697978  555.000000  555.000000

# %% [markdown]
# ## Statistics

# %% [markdown]
# Operations in general exclude missing data.

# %%
df.mean()
# Out:
# prob_RA    0.447155
# prob_SN    0.488661
# prob_ZR    0.400995
# prob_IP    0.498643
# dtype: float64

# %% [markdown]
# Same operation, other axis:

# %%
df.mean(1)
# Out:
# 2019-02-11    0.460250
# 2019-02-12    0.464897
# 2019-02-13    0.314993
# 2019-02-14    0.383628
# 2019-02-15    0.508108
# 2019-02-16    0.621303
# Freq: D, dtype: float64

# %% [markdown]
# ## Getting Data In/Out

# %%
df.to_csv('my_csv.csv') #Write out dataframe to CSV

# %%
df = pd.read_csv('https://www.spc.noaa.gov/wcm/data/2016_hail.csv') # U.S. Hail Reports for 2016

# %%
df.head()
# Out:
#        om    yr  mo  dy        date      time  tz  st  stf  stn ...     elon  \
# 0  613211  2016   1   8  2016-01-08  16:48:00   3  LA   22    0 ... -93.5800
# 1  613212  2016   1   8  2016-01-08  17:57:00   3  TX   48    0 ... -94.6765
# 2  613213  2016   1   8  2016-01-08  18:00:00   3  TX   48    0 ... -94.7236
# 3  613214  2016   1   8  2016-01-08  18:00:00   3  TX   48    0 ... -95.4700
# 4  613215  2016   1   8  2016-01-08  18:00:00   3  TX   48    0 ... -95.5500
#
#    len  wid  ns  sn  sg   f1  f2  f3  f4
# 0    0    0   0   0   0   19   0   0   0
# 1    0    0   0   0   0  347   0   0   0
# 2    0    0   0   0   0    5   0   0   0
# 3    0    0   0   0   0  471   0   0   0
# 4    0    0   0   0   0  471   0   0   0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Get all the reports for the month of June

# %%
df.query('mo==6')
# Out:
#           om    yr  mo  dy        date      time  tz  st  stf  stn ...  \
# 5108  618319  2016   6   1  2016-06-01  13:50:00   3  GA   13    0 ...
# 5109  618320  2016   6   1  2016-06-01  13:50:00   3  TX   48    0 ...
# 5110  618321  2016   6   1  2016-06-01  14:40:00   3  GA   13    0 ...
# 5111  618322  2016   6   1  2016-06-01  14:50:00   3  FL   12    0 ...
# 5112  618323  2016   6   1  2016-06-01  15:12:00   3  GA   13    0 ...
# 5113  618324  2016   6   1  2016-06-01  15:13:00   3  TX   48    0 ...
# 5114  618325  2016   6   1  2016-06-01  15:20:00   3  MI   26    0 ...
# 6422 -100.6300    0    0   0   0   0   69   0   0   0
# 6423  -93.2100    0    0   0   0   0  131   0   0   0
# 6424  -96.7400    0    0   0   0   0   39   0   0   0
# 6425  -82.3800    0    0   0   0   0    1   0   0   0
# 6426  -82.2400    0    0   0   0   0   47   0   0   0
# 6427  -92.3300    0    0   0   0   0   17   0   0   0
# 6428  -82.9400    0    0   0   0   0  147   0   0   0
# 6429 -115.4379    0    0   0   0   0    3   0   0   0
# 6430  -93.9900    0    0   0   0   0   81   0   0   0
# 6431  -84.0194    0    0   0   0   0  207   0   0   0
# 6432 -115.0289    0    0   0   0   0    3   0   0   0
# 6433  -82.7500    0    0   0   0   0   77   0   0   0
# 6434  -82.6900    0    0   0   0   0   77   0   0   0
# 6435 -112.1800    0    0   0   0   0   99   0   0   0
# 6436  -97.4000    0    0   0   0   0  191   0   0   0
# 6437 -112.5224    0    0   0   0   0   35   0   0   0
# 6438  -79.8800    0    0   0   0   0   25   0   0   0
# 6439  -79.9100    0    0   0   0   0   25   0   0   0
# 6440  -94.4700    0    0   0   0   0   97   0   0   0
# 6441  -89.8400    0    0   0   0   0   73   0   0   0
# 6442 -110.0800    0    0   0   0   0   41   0   0   0
# 6443  -97.8500    0    0   0   0   0   17   0   0   0
# 6444 -102.0200    0    0   0   0   0  181   0   0   0
# 6445  -76.9500    0    0   0   0   0  620   0   0   0
# 6446  -81.4500    0    0   0   0   0   27   0   0   0
# 6447  -81.4100    0    0   0   0   0   27   0   0   0
#
# [1340 rows x 28 columns]

# %% [markdown]
# ## Get 2 inch or greater reports for the month of March in the state of IL

# %%
df.query("st=='IL' & mo==3 & mag>=2")
# Out:
#          om    yr  mo  dy        date      time  tz  st  stf  stn ...   elon  \
# 423  613634  2016   3  15  2016-03-15  16:53:00   3  IL   17    0 ... -90.97
# 452  613663  2016   3  15  2016-03-15  17:59:00   3  IL   17    0 ... -90.23
# 454  613665  2016   3  15  2016-03-15  18:20:00   3  IL   17    0 ... -90.03
#
#      len  wid  ns  sn  sg   f1  f2  f3  f4
# 423    0    0   0   0   0   67   0   0   0
# 452    0    0   0   0   0  137   0   0   0
# 454    0    0   0   0   0  137   0   0   0
#
# [3 rows x 28 columns]

# %% [markdown]
# ### xarray (xarray: N-D labeled arrays and datasets in Python)   http://xarray.pydata.org/en/stable/
# - Multi-dimensional (a.k.a. N-dimensional, ND) arrays (sometimes called “tensors”) are an essential part of computational science. They are encountered in a wide range of fields, including physics, astronomy, geoscience, bioinformatics, engineering, finance, and deep learning. In Python, NumPy provides the fundamental data structure and API for working with raw ND arrays. However, real-world datasets are usually more than just raw numbers; they have labels which encode information about how the array values map to locations in space, time, etc.
#
# - By introducing dimensions, coordinates, and attributes on top of raw NumPy-like arrays, xarray is able to understand these labels and use them to provide a more intuitive, more concise, and less error-prone experience. Xarray also provides a large and growing library of functions for advanced analytics and visualization with these data structures. Xarray was inspired by and borrows heavily from pandas, the popular data analysis package focused on labelled tabular data. Xarray can read and write data from most common labeled ND-array storage formats and is particularly tailored to working with netCDF files, which were the source of xarray’s data model.

# %%
import xarray as xr

# %%
narr = xr.open_dataset('http://www.esrl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis/surface/lftx.sfc.2011.nc')

# %%
narr
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 73, lon: 144, time: 1460)
# Coordinates:
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * time     (time) datetime64[ns] 2011-01-01 ... 2011-12-31T18:00:00
# Data variables:
#     lftx     (time, lat, lon) float32 ...
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2011)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     history:                         created 2011/01 by Hoop (netCDF2.3)\nCon...
#     References:                      http://www.esrl.noaa.gov/psd/data/gridde...
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     DODS_EXTRA.Unlimited_Dimension:  time

# %%
narr.sel(time='2011-04-27T18').lftx
# Out:
# <xarray.DataArray 'lftx' (lat: 73, lon: 144)>
# array([[15.600006, 15.600006, 15.600006, ..., 15.600006, 15.600006, 15.600006],
#        [14.100006, 14.      , 13.899994, ..., 14.5     , 14.299988, 14.200012],
#        [16.799988, 16.200012, 15.700012, ..., 19.      , 18.200012, 17.5     ],
#        ...,
#        [25.100006, 24.700012, 24.399994, ..., 25.100006, 25.200012, 25.200012],
#        [26.100006, 26.100006, 26.100006, ..., 25.899994, 26.      , 26.      ],
#        [24.100006, 24.100006, 24.100006, ..., 24.100006, 24.100006, 24.100006]],
#       dtype=float32)
# Coordinates:
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#     time     datetime64[ns] 2011-04-27T18:00:00
# Attributes:
#     long_name:     4xDaily Surface Lifted Index
#     units:         degK
#     precision:     2
#     GRIB_id:       131
#     GRIB_name:     LFT_X
#     var_desc:      Surface Lifted Index
#     level_desc:    Surface
#     statistic:     Individual Obs
#     parent_stat:   Other
#     actual_range:  [-13.200012  63.600006]
#     valid_range:   [-18.  70.]
#     dataset:       NCEP Reanalysis
#     _ChunkSizes:   [  1  73 144]

# %%
narr.sel(time='2011-04-27T18').lftx.values
# Out:
# array([[15.600006, 15.600006, 15.600006, ..., 15.600006, 15.600006,
#         15.600006],
#        [14.100006, 14.      , 13.899994, ..., 14.5     , 14.299988,
#         14.200012],
#        [16.799988, 16.200012, 15.700012, ..., 19.      , 18.200012,
#         17.5     ],
#        ...,
#        [25.100006, 24.700012, 24.399994, ..., 25.100006, 25.200012,
#         25.200012],
#        [26.100006, 26.100006, 26.100006, ..., 25.899994, 26.      ,
#         26.      ],
#        [24.100006, 24.100006, 24.100006, ..., 24.100006, 24.100006,
#         24.100006]], dtype=float32)

# %%
narr.sel(time='2011-04-27T18').lftx.values.shape
# Out:
# (73, 144)

# %%
plt.pcolormesh(narr.sel(time='2011-04-27T18').lftx.values)

# %%
plt.pcolormesh(narr.sel(time='2011-04-27T18').lon.values, narr.sel(time='2011-04-27T18').lat.values,narr.sel(time='2011-04-27T18').lftx.values)
